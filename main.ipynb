# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
dados = pd.read_csv("slr12.csv", sep=";")
#dados.shape
dados.head()
# Out:
#    FrqAnual  CusInic
# 0      1000     1050
# 1      1125     1150
# 2      1087     1213
# 3      1070     1275
# 4      1100     1300

# %%
x=dados.iloc[:,0].values
y=dados.iloc[:,1].values

# %%
correlacao=np.corrcoef(x,y)
x=x.reshape(-1,1)
modelo=LinearRegression()
modelo.fit(x,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)
plt.plot(x, modelo.predict(x), color='blue')

# %%
# Na variável coloca um valor de Franquia Anual para ele prever qual vai ser o Investimento Inicial necessário.
prever_invini=1350
modelo.predict([[prever_invini]])
# É o valor do array em reais!
# Out:
# array([1371.36743577])
